# %%
import main
import plot_inequality as plot_ineq
import time
import importlib
import io_manager
importlib.reload(plot_ineq)
#run stuff here
start_time = time.perf_counter()
print("Running main")

of_name = None
main_path = "C:/Users/Ben/My Drive/PhD/PhD Year 3/3rd Year Paper/Model/My Code/MH_Model/my_code/model_uncert/"
trans_path = main_path + "input/50p_age_moms/MH_trans_uncond_age.csv"
main_path = "C:/Users/Ben/My Drive/PhD/PhD Year 3/3rd Year Paper/Model/My Code/MH_Model/my_code/model_uncert/"

output_flag = False
myPars, myShocks, sols, sims = main.main_io(main_path, out_folder_name = of_name, H_trans_uncond_path = trans_path, output_flag = output_flag)
# Out:
# Running main
# *****Running main_io with default out_folder_name*****
# Solver ran in 7.978096299993922 seconds
# Calibrating with alpha_lab_targ = 0.33495033, w0_mean_targ = 2.1986368, w0_sd_targ = 0.29955208,
#                                         w1_targ = 0.2915730000000001, w2_targ = 0.2731836000000003, wH_targ = 0.051262233,
#                                         dpi_BB_targ = 0.50886095, dpi_GG_targ = 0.34358001
# ***** Calibration iteration 0 *****
# Calibrating delta_pi_GG
# my_dpi_BB_mom: 0.469230422789032, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# ***** Calibration iteration 1 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# ***** Calibration iteration 2 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# ***** Calibration iteration 3 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# ***** Calibration iteration 4 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# ***** Calibration iteration 5 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# ***** Calibration iteration 6 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# ***** Calibration iteration 7 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# ***** Calibration iteration 8 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# ***** Calibration iteration 9 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# Calibrating wH
# ***** Calibration iteration 10 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# ***** Calibration iteration 11 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# ***** Calibration iteration 12 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# ***** Calibration iteration 13 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# ***** Calibration iteration 14 *****
# my_dpi_BB_mom: 0.5325366055556626, my_dpi_GG_mom: 0.34338303924920055
# Calibrating w0_mu
# Calibrating w0_sigma
# Calibrating w1
# Calibrating w2
# Calibrating wH
# Calibrating alpha
# Calibration converged after 15 iterations
# delta_pi_BB = 0.0, delta_pi_BB mom = 0.5325366055556626, delta_pi_BB mom targ = 0.50886095
# delta_pi_GG = 0.3134765625, delta_pi_GG mom = 0.34338303924920055, delta_pi_GG mom targ = 0.34358001
# w0_weights = [0.08027629 0.21838255 0.26111867 0.19979135 0.12018334 0.0631795
#  0.03076245 0.01434975 0.00654538 0.00541072], w0_mean = 2.1977305581581104, w0_mean_targ = 2.1986368
# w0_sd = 0.29874625565470125, w0_sd_targ = 0.29955208
# w1 = 0.0225067138671875, w1 moment = 0.2912568173101411, w1 mom targ = 0.2915730000000001
# w2 = -0.00044727325439453125, w2 moment = 0.27373220200733916, w2 mom targ = 0.2731836000000003
# wH = 0.0439453125, wH moment = 0.051732140395164716, wH mom targ = 0.051262233
# alpha = 0.3789124609375, alpha moment = 0.33549729229450653, alpha mom targ = 0.33495033
# Calibration ran in 285.4557571999976 seconds

# %%
import plot_aggregates
import io_manager as io
importlib.reload(plot_aggregates)
outpath = main_path + "/validation/"
trans_name = "MH_trans_uncond_age"
my_trans = io.read_and_shape_H_trans_uncond_age(myPars, trans_path)
# print(my_trans)
myPars.H_trans = my_trans
# print(myPars.H_trans)
plot_aggregates.plot_H_trans_uncond(myPars, outpath, trans_name)
