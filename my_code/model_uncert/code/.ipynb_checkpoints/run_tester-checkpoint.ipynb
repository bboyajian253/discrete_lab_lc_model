# %%
# import stuff
# my code
import model_no_uncert as model
import my_toolbox as tb
from pars_shocks_and_wages import Pars, Shocks
import plot_lc
import run
import simulate
import solver

# general
import numpy as np

# %%
main_path = "C:/Users/Ben/My Drive/PhD/PhD Year 3/3rd Year Paper/Model/My Code/Main_Git_Clone/Model/My Code/my_model_2/output/"

# my_lab_FE_grid = np.array([10.0, 20.0, 30.0, 40.0])
my_lab_FE_grid = np.array([10.0, 20.0, 30.0])
lin_wage_coeffs = [0.0, 0.5, 0.5, 0.5]
quad_wage_coeffs = [-0.000, -0.020, -0.020, -0.020] 
cub_wage_coeffs = [0.0, 0.0, 0.0, 0.0]

num_FE_types = len(my_lab_FE_grid)
w_coeff_grid = np.zeros([num_FE_types, 4])
    
w_coeff_grid[0, :] = [my_lab_FE_grid[0], lin_wage_coeffs[0], quad_wage_coeffs[0], cub_wage_coeffs[0]]
w_coeff_grid[1, :] = [my_lab_FE_grid[1], lin_wage_coeffs[1], quad_wage_coeffs[1], cub_wage_coeffs[1]]
w_coeff_grid[2, :] = [my_lab_FE_grid[2], lin_wage_coeffs[2], quad_wage_coeffs[2], cub_wage_coeffs[2]]
#w_coeff_grid[3, :] = [my_lab_FE_grid[3], lin_wage_coeffs[3], quad_wage_coeffs[3], cub_wage_coeffs[3]]

print("intial wage coeff grid")
print(w_coeff_grid)

myPars = Pars(main_path, J=50, a_grid_size=5, a_min= -500.0, a_max = 500.0, lab_FE_grid = my_lab_FE_grid,
            H_grid=np.array([0.0, 1.0]), nu_grid_size=1, alpha = 0.45, sim_draws=1000,
            wage_coeff_grid = w_coeff_grid,
            print_screen=3)
myShocks = Shocks(myPars)
state_sols = solver.solve_lc(myPars)
# Out:
# intial wage coeff grid
# [[ 1.e+01  0.e+00 -0.e+00  0.e+00]
#  [ 2.e+01  5.e-01 -2.e-02  0.e+00]
#  [ 3.e+01  5.e-01 -2.e-02  0.e+00]]
# state_sols shape (5, 3, 2, 1, 50)
# solved period 49 of 50
# solved period 48 of 50
# solved period 47 of 50
# solved period 46 of 50
# solved period 45 of 50
# solved period 44 of 50
# solved period 43 of 50
# solved period 42 of 50
# solved period 41 of 50
# solved period 40 of 50
# solved period 39 of 50
# solved period 38 of 50
# solved period 37 of 50
# solved period 36 of 50
# solved period 35 of 50
# solved period 34 of 50
# solved period 33 of 50
# solved period 32 of 50
# solved period 31 of 50
# solved period 30 of 50
# solved period 29 of 50
# solved period 28 of 50
# solved period 27 of 50
# solved period 26 of 50
# solved period 25 of 50
# solved period 24 of 50
# solved period 23 of 50
# solved period 22 of 50
# solved period 21 of 50
# solved period 20 of 50
# solved period 19 of 50
# solved period 18 of 50
# solved period 17 of 50
# solved period 16 of 50
# solved period 15 of 50
# solved period 14 of 50
# solved period 13 of 50
# solved period 12 of 50
# solved period 11 of 50
# solved period 10 of 50
# solved period 9 of 50
# solved period 8 of 50
# solved period 7 of 50
# solved period 6 of 50
# solved period 5 of 50
# solved period 4 of 50
# solved period 3 of 50
# solved period 2 of 50
# solved period 1 of 50
# solved period 0 of 50

# %%
asset_ind = 3
fe_ind = 0
h_ind = 1
nu_ind = 0
for j in range(myPars.J):
    print(f"For j={j}: {state_sols['lab'][asset_ind, fe_ind, h_ind, nu_ind, j]}")
# Out:
# For j=0: 0.7202522011544159
# For j=1: 0.7192918451724123
# For j=2: 0.7182881572044872
# For j=3: 0.7172383473977595
# For j=4: 0.7161393824298221
# For j=5: 0.7149879583371801
# For j=6: 0.7137804696212724
# For j=7: 0.7125129740232283
# For j=8: 0.7111811522419753
# For j=9: 0.7097802617280767
# For j=10: 0.7083050835112594
# For j=11: 0.7067498608047353
# For j=12: 0.7051082278633775
# For j=13: 0.703373127241722
# For j=14: 0.7015367131834184
# For j=15: 0.6995902383522503
# For j=16: 0.6975239204544557
# For j=17: 0.6953267844604796
# For j=18: 0.6929864750544834
# For j=19: 0.6904890325445519
# For j=20: 0.687818623649716
# For j=21: 0.6849572161952571
# For j=22: 0.6818841835910128
# For j=23: 0.6785758207504633
# For j=24: 0.6750047474202234
# For j=25: 0.6711391671369412
# For j=26: 0.6669419393439494
# For j=27: 0.6623694072972149
# For j=28: 0.6573699033339749
# For j=29: 0.6518818229092086
# For j=30: 0.64583111492202
# For j=31: 0.6391279709598832
# For j=32: 0.6316623983776357
# For j=33: 0.623298212062891
# For j=34: 0.6138647441786105
# For j=35: 0.6031451923383336
# For j=36: 0.5908599007164846
# For j=37: 0.5766418024210863
# For j=38: 0.5599993718989221
# For j=39: 0.54025898987173
# For j=40: 0.5164720111601686
# For j=41: 0.4872584489862083
# For j=42: 0.45053037216653746
# For j=43: 0.40297113794276823
# For j=44: 0.3389756334162872
# For j=45: 0.2482650261581093
# For j=46: 0.20193512056108243
# For j=47: 0.26697710516103984
# For j=48: 0.3960396039603959
# For j=49: 0.0

# %%
sim_lc = simulate.sim_lc(myPars, myShocks, state_sols)

# %%
print(sim_lc['lab'])
# Out:
# [[[[[ 3.60000000e-01  3.60000000e-01  3.60000000e-01 ...
#       3.60000000e-01  3.60000000e-01 -9.99900000e+03]
#     [ 3.60000000e-01  3.60000000e-01  3.60000000e-01 ...
#       3.60000000e-01  3.60000000e-01 -9.99900000e+03]
#     [ 3.60000000e-01  3.60000000e-01  3.60000000e-01 ...
#       3.60000000e-01  3.60000000e-01 -9.99900000e+03]
#     ...
#     [ 3.60000000e-01  3.60000000e-01  3.60000000e-01 ...
#       3.60000000e-01  3.60000000e-01 -9.99900000e+03]
#     [ 3.60000000e-01  3.60000000e-01  3.60000000e-01 ...
#       3.60000000e-01  3.60000000e-01 -9.99900000e+03]
#     [ 3.60000000e-01  3.60000000e-01  3.60000000e-01 ...
#       3.60000000e-01  3.60000000e-01 -9.99900000e+03]]]
#
#
#   [[[ 4.00000000e-01  4.00000000e-01  4.00000000e-01 ...
#       4.00000000e-01  4.00000000e-01 -9.99900000e+03]
#     [ 4.00000000e-01  4.00000000e-01  4.00000000e-01 ...
#       4.00000000e-01  4.00000000e-01 -9.99900000e+03]
#     [ 4.00000000e-01  4.00000000e-01  4.00000000e-01 ...
#       4.00000000e-01  4.00000000e-01 -9.99900000e+03]
#     ...
#     [ 4.00000000e-01  4.00000000e-01  4.00000000e-01 ...
#       4.00000000e-01  4.00000000e-01 -9.99900000e+03]
#     [ 4.00000000e-01  4.00000000e-01  4.00000000e-01 ...
#       4.00000000e-01  4.00000000e-01 -9.99900000e+03]
#     [ 4.00000000e-01  4.00000000e-01  4.00000000e-01 ...
#       4.00000000e-01  4.00000000e-01 -9.99900000e+03]]]]
#
#
#
#  [[[[ 2.05225858e-01  2.33010026e-01  2.57324575e-01 ...
#       9.12733578e-02  3.50922234e-02 -9.99900000e+03]
#     [ 2.05225858e-01  2.33010026e-01  2.57324575e-01 ...
#       9.12733578e-02  3.50922234e-02 -9.99900000e+03]
#     [ 2.05225858e-01  2.33010026e-01  2.57324575e-01 ...
#       9.12733578e-02  3.50922234e-02 -9.99900000e+03]
#     ...
#     [ 2.05225858e-01  2.33010026e-01  2.57324575e-01 ...
#       9.12733578e-02  3.50922234e-02 -9.99900000e+03]
#     [ 2.05225858e-01  2.33010026e-01  2.57324575e-01 ...
#       9.12733578e-02  3.50922234e-02 -9.99900000e+03]
#     [ 2.05225858e-01  2.33010026e-01  2.57324575e-01 ...
#       9.12733578e-02  3.50922234e-02 -9.99900000e+03]]]
#
#
#   [[[ 2.28129509e-01  2.58995519e-01  2.86007763e-01 ...
#       9.83392706e-02  4.89373192e-02 -9.99900000e+03]
#     [ 2.28129509e-01  2.58995519e-01  2.86007763e-01 ...
#       9.83392706e-02  4.89373192e-02 -9.99900000e+03]
#     [ 2.28129509e-01  2.58995519e-01  2.86007763e-01 ...
#       9.83392706e-02  4.89373192e-02 -9.99900000e+03]
#     ...
#     [ 2.28129509e-01  2.58995519e-01  2.86007763e-01 ...
#       9.83392706e-02  4.89373192e-02 -9.99900000e+03]
#     [ 2.28129509e-01  2.58995519e-01  2.86007763e-01 ...
#       9.83392706e-02  4.89373192e-02 -9.99900000e+03]
#     [ 2.28129509e-01  2.58995519e-01  2.86007763e-01 ...
#       9.83392706e-02  4.89373192e-02 -9.99900000e+03]]]]
#
#
#
#  [[[[ 2.58542306e-01  2.75671006e-01  2.91111832e-01 ...
#       9.04990734e-02  7.68689212e-02 -9.99900000e+03]
#     [ 2.58542306e-01  2.75671006e-01  2.91111832e-01 ...
#       9.04990734e-02  7.68689212e-02 -9.99900000e+03]
#     [ 2.58542306e-01  2.75671006e-01  2.91111832e-01 ...
#       9.04990734e-02  7.68689212e-02 -9.99900000e+03]
#     ...
#     [ 2.58542306e-01  2.75671006e-01  2.91111832e-01 ...
#       9.04990734e-02  7.68689212e-02 -9.99900000e+03]
#     [ 2.58542306e-01  2.75671006e-01  2.91111832e-01 ...
#       9.04990734e-02  7.68689212e-02 -9.99900000e+03]
#     [ 2.58542306e-01  2.75671006e-01  2.91111832e-01 ...
#       9.04990734e-02  7.68689212e-02 -9.99900000e+03]]]
#
#
#   [[[ 2.87466932e-01  3.06492399e-01  3.23643320e-01 ...
#       5.92405120e-02  4.38524699e-02 -9.99900000e+03]
#     [ 2.87466932e-01  3.06492399e-01  3.23643320e-01 ...
#       5.92405120e-02  4.38524699e-02 -9.99900000e+03]
#     [ 2.87466932e-01  3.06492399e-01  3.23643320e-01 ...
#       5.92405120e-02  4.38524699e-02 -9.99900000e+03]
#     ...
#     [ 2.87466932e-01  3.06492399e-01  3.23643320e-01 ...
#       5.92405120e-02  4.38524699e-02 -9.99900000e+03]
#     [ 2.87466932e-01  3.06492399e-01  3.23643320e-01 ...
#       5.92405120e-02  4.38524699e-02 -9.99900000e+03]
#     [ 2.87466932e-01  3.06492399e-01  3.23643320e-01 ...
#       5.92405120e-02  4.38524699e-02 -9.99900000e+03]]]]]

# %%
run.output(myPars, state_sols, sim_lc)
# Out:
#  Consumption
# log Consumption
#  Labor
# log Labor
#  Assets
# log Assets
#  Wage
# log Wage
#  Labor Income
# log Labor Income
